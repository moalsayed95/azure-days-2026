# %% [markdown]
# # 🐍 AI Travel Agent with Microsoft Agent Framework (Python)
#
# ## 📋 Scenario Overview
#
# This notebook demonstrates how to build an intelligent travel planning agent using the Microsoft Agent Framework for Python. The agent leverages Azure AI Foundry to automatically generate personalized day-trip itineraries for random destinations worldwide.
#
# **Key Features:**
# - 🎲 **Smart Destination Selection**: Custom tool function for random destination picking
# - 🗺️ **Detailed Itinerary Generation**: AI-powered travel planning with local recommendations
# - 🔄 **Async Processing**: Uses asyncio for efficient API communication
# - 🛠️ **Tool Integration**: Demonstrates function calling capabilities in AI agents
#
# ## 🏗️ Technical Implementation
#
# ### Core Components
# - **Agent Framework**: Python implementation of Microsoft's agent orchestration system
# - **Azure AI Foundry**: Access to state-of-the-art language models via Azure OpenAI service
# - **OpenAI Compatibility**: Uses OpenAI client patterns with Azure AI Foundry backend
# - **Environment Management**: Secure credential handling with python-dotenv
#
# ### Architecture Flow
# ```python
# User Request → ChatAgent → Azure AI Foundry API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Key Classes & Methods
# - `ChatAgent`: Main conversational agent orchestrator
# - `OpenAIChatClient`: Azure AI Foundry API client wrapper
# - `get_random_destination()`: Custom tool function for destination selection
# - Environment variables: Secure API configuration management
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com/openai/v1/
# AZURE_OPENAI_API_KEY=your_api_key_here
# AZURE_OPENAI_MODEL_ID=gpt-4o-mini
# ```
#
# **Azure AI Foundry Access:**
# 1. Create an Azure OpenAI resource in the Azure Portal
# 2. Deploy a model (e.g., gpt-4o-mini)
# 3. Get your endpoint and API key from Keys & Endpoint section
# 4. Configure environment variables as shown above
#
# ## 🚀 Usage Instructions
#
# Execute the cells below in sequence to:
# 1. Import required libraries and load environment variables
# 2. Define the random destination generator tool
# 3. Create and configure the AI agent
# 4. Run travel planning requests and view results
#
# Let's build an intelligent travel planning assistant! 🌟

# %%
! pip install agent-framework-core -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: agent-framework-core in /home/vscode/.local/lib/python3.12/site-packages (1.0.0b260107)
# Requirement already satisfied: typing-extensions in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (2.15.0)
# Requirement already satisfied: azure-identity<2,>=1 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp>=1.23 in /home/vscode/.local/lib/python3.12/site-packages (from mcp[ws]>=1.23->agent-framework-core) (1.25.0)
# Requirement already satisfied: packaging>=24.1 in /home/vscode/.local/lib/python3.12/site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.local/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/vscode/.local/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/vscode/.local/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/vscode/.local/lib/python3.12/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: requests>=2.21.0 in /home/vscode/.local/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: anyio>=4.5 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/vscode/.local/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (3.1.2)
# Requirement already satisfied: starlette>=0.27 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/vscode/.local/lib/python3.12/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.40.0)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.local/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (3.11)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.30.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/vscode/.local/lib/python3.12/site-packages (from mcp[ws]>=1.23->agent-framework-core) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/vscode/.local/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in /home/vscode/.local/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/vscode/.local/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/vscode/.local/lib/python3.12/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.local/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/vscode/.local/lib/python3.12/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: click>=7.0 in /home/vscode/.local/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (8.3.1)

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: AZURE_OPENAI_ENDPOINT, AZURE_OPENAI_API_KEY, AZURE_OPENAI_DEPLOYMENT_NAME
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for Azure AI Foundry
# This client connects to Azure AI Foundry API (OpenAI-compatible endpoint)
# Environment variables required:
# - AZURE_OPENAI_ENDPOINT: API endpoint URL (e.g., https://<resource>.openai.azure.com/openai/v1/)
# - AZURE_OPENAI_API_KEY: Your Azure OpenAI API key
# - AZURE_OPENAI_DEPLOYMENT_NAME: Model deployment name (e.g., gpt-4o-mini)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"), 
    model_id=os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 📦 Install DevUI Package (if not already installed)
# DevUI is a separate package that provides a web interface for agent development
! pip install agent-framework-devui --pre -q

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# I've chosen Berlin, Germany, as your destination for a day trip! Here's a suggested itinerary:
#
# ### Morning
# - **Breakfast at a Local Café**: Start your day with a hearty breakfast at a popular café. Try some German pastries, like a Berliner doughnut and a cup of coffee.
#
# - **Visit the Brandenburg Gate**: Head over to this iconic landmark to enjoy the impressive architecture and take some great photos.
#
# ### Late Morning
# - **Explore the Berlin Wall Memorial**: Visit this historical site to learn about the history of the Berlin Wall and its significance.
#
# ### Lunch
# - **Lunch at a Traditional German Beer Garden**: Enjoy a traditional German meal. Don’t forget to try some Bratwurst with sauerkraut and a local beer.
#
# ### Afternoon
# - **Tour the Reichstag Building**: Visit the home of the German parliament, and be sure to go up to the glass dome for panoramic views of the city.
#
# - **Stroll through Tiergarten**: Take a leisurely walk in Berlin's most famous park, where you can relax and enjoy nature.
#
# ### Evening
# - **Dinner in Mitte**: Head to the Mitte district for dinner. There are plenty of restaurants serving various cuisines.
#
# - **Nighttime Visit to the Berlin Eye**: Cap off your day with a ride on the Berlin Eye for stunning nighttime views of the city.
#
# ### Optional Night Activity
# - **Check Out a Local Bar or Pub**: If you’re up for it, explore Berlin's vibrant nightlife!
#
# Enjoy your day trip to Berlin!

# %% [markdown]
# # 🎛️ Launch DevUI (Optional)
#
# DevUI provides an interactive web interface for testing and debugging the agent. It offers:
# - Chat interface with the agent
# - Debug panel showing HTTP requests, traces, and tool calls
# - Real-time streaming of responses
# - OpenAI-compatible API endpoints
#
# Run the cell below to launch DevUI. It will automatically open your browser at http://localhost:8080.

# %%
import subprocess
import signal
import os

# 🚀 Launch DevUI Web Interface
# First, kill any previous instances running on port 8080
print("🔍 Checking for existing DevUI instances on port 8080...")

try:
    # Find processes using port 8080
    result = subprocess.run(
        ["lsof", "-ti", ":8080"],
        capture_output=True,
        text=True,
        timeout=5
    )
    
    if result.stdout.strip():
        pids = result.stdout.strip().split('\n')
        for pid in pids:
            try:
                os.kill(int(pid), signal.SIGTERM)
                print(f"✅ Killed previous instance (PID: {pid})")
            except ProcessLookupError:
                pass
            except Exception as e:
                print(f"⚠️  Could not kill PID {pid}: {e}")
    else:
        print("✅ No existing instances found")
except FileNotFoundError:
    # lsof not available, try alternative method
    try:
        result = subprocess.run(
            ["fuser", "-k", "8080/tcp"],
            capture_output=True,
            text=True,
            timeout=5
        )
        print("✅ Cleaned up any existing instances")
    except:
        print("✅ No cleanup needed")
except Exception as e:
    print(f"ℹ️  Cleanup check skipped: {e}")

# Launch the DevUI server
print("\n🎛️ Launching DevUI at http://localhost:8080...")
subprocess.Popen(["python3", "launch_devui.py"], 
                 stdout=subprocess.DEVNULL, 
                 stderr=subprocess.DEVNULL)
print("✅ DevUI server started!")
print("📝 Check your browser at http://localhost:8080")
# Out:
# 🔍 Checking for existing DevUI instances on port 8080...
# ✅ No existing instances found
#
# 🎛️ Launching DevUI at http://localhost:8080...
# ✅ DevUI server started!
# 📝 Check your browser at http://localhost:8080
